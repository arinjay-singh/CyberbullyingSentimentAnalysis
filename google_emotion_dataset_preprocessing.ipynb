# %%
import pandas as pd
from nltk import word_tokenize
from gensim.models import Word2Vec

# %%
df = pd.read_csv("go_emotions_dataset.csv")

non_neg_cols = [
    "text",
    "example_very_unclear",
    "admiration",
    "amusement",
    "approval",
    "caring",
    "desire",
    "excitement",
    "gratitude",
    "joy",
    "love",
    "optimism",
    "pride",
    "love",
    "fear",
    "grief",
    "embarrassment",
    "nervousness",
    "remorse",
    "sadness",
]

neg_cols = ["anger", "annoyance", "disappointment", "disapproval", "disgust"]

df_non_neg = df.loc[df[non_neg_cols].eq(1).any(axis=1), non_neg_cols]

df_neg = df.loc[df[neg_cols].eq(1).any(axis=1), neg_cols]

df_neg.head()
# Out:
#     anger  annoyance  disappointment  disapproval  disgust
# 6       0          0               0            1        0
# 11      0          0               1            0        0
# 13      0          0               1            0        1
# 19      0          1               0            0        0
# 29      0          0               0            0        1
